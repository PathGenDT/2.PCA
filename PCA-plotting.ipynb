# %% [markdown]
# # Plotting PCA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # loading files

# %%
pca = pd.read_table("./2.PCA/plink_results_projected.sscore",sep="\t")
pca

# %%
ped = pd.read_table("./2.PCA/integrated_call_samples_v3.20130502.ALL.panel",sep="\t")
ped

# %% [markdown]
# # Merge PCA and population information

# %%
pcaped=pd.merge(pca,ped,right_on="sample",left_on="IID",how="inner")
pcaped

# %% [markdown]
# # Plotting

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=pcaped,x="PC1_AVG",y="PC2_AVG",hue="pop",s=50)
